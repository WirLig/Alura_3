# %% [markdown]
# <a href="https://colab.research.google.com/github/WirLig/Alura_3/blob/main/WiramLigeiro_3%C2%AA_ImersaoDadosAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão Dados Alura - 3ª Edição
# # Projeto de Data Science com base Python
#
# ## Estudo conjunto durante as Vídeo-aulas e Lives
# #### Esse projeto da ALURA foi inspirado em um desafio do Laboratory Innovation Science at Harvard disponibilizando os dados em uma competição no kaggle.

# %% [markdown]
# #### Wiram Ligeiro  --  https://www.linkedin.com/in/wiram-ligeiro-51565636/

# %% [markdown]
# ![about-3887443__340.webp](data:image/webp;base64,...)

# %% [markdown]
# ## Semana de Imersão em Dados
# ## Dia 1 - Análise de dados, python, pandas e novos fármacos

# %% [markdown]
# ## Introdução
#
# #### Empresas farmacêuticas desenvolvem pequisas e inovações de forma independente assim como em parceria mútua com outras organizaçãoes concorrentes, universidades e institutos de pequisas que impactam positivamente o panorama dos estudos clínicos.
#
# #### Inovações tecnológicas surgem de testes mais eficientes, que podem diminuir o tempo de estudo, além de resultar em dados mais ricos e precisos. A análise de dados são ferramentas cruciais para a melhor fluidez das fases e resultados das pesquisas.
#
#
#
# ## Pipeline para a pesquisa de novos medicamentos
# Doença a ser pesquisada e tratada;
# Identificação do foco da droga;
# Desenvolvimento de agentes biológicos ou moleculares em laboratório;
# Triagem para confrontar substâncias alinhadas ao foco da pesquisa para novos denvolvimentos;
# Testes laboratoriais dos possíveis elementos atuando em colônicas de células como candidatos ao combate da doença.
#
#
#
# ## Tópicos para o Estudo e Projeto de Análise de Dados
# Análise de dados, python, pandas e novos fármacos;
# Estatísticas, visualização de dados e distribuições;
# Correlações Causalidades e Relações entre genes;
# Merge e Análise de resultados;
# Machine Learning e Sci-kit Learning

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head
# Out:
# <bound method NDFrame.head of                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# #### agora, conhecer tipos de entidades, atributos ou valores únicos de cada coluna, dados a analisar, com a função 'unique'.

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# #### Agora, conhecer a distribuição / frequencia de resultados nos experimentos.

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# #### Desafio 1 - No resultado acima, possíveis causas (?), por que a classe 'tratamento' é tão desbalanceada?

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Função normalize, para calcular valores percentuais da amostra

# %% [markdown]
# #### - Desafio 3 - Proporção da classe "tratamento' %

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ##### - Desafio 2 - Plotar as ultimas 5 linhas da tabela
#
# ##### - Desafio 4 - Quantos tipos de drogas foram pesquisadas?

# %% [markdown]
# ##### - Desafio 5 - procurar na documentação do pandas o método query.
# ##### - Desafio 6 - nos graficos, colocar título, labels, e melhorar a informação - consultar matplotlib.
# ##### - Desafio 7 - renomear colunas retirando os hifens - Python não trabalha bem com o hifen.
# ##### - Desafio 8 - Fazer resumo do que  foi aprendido com os dados, plotar gráficos para outras variáveis, e analisar.

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie() ##### Melhorar visualização do resultado com grafico tipo barra.

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# #### Agora: qtos elementos na coluna g-0 são maiores que zero? faz sentido para a pesquisa? Exercicio  de reflexão...

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Resumo dos desafios formulados:
# Desafio 1 - Por que a classe 'tratamento' é tão desbalanceada?
# Desafio 2 - Plotar as ultimas 5 linhas da tabela
# Desafio 3 - Proporção da classe "tratamento' %
# Desafio 4 - Quantos tipos de drogas foram pesquisadas?
# Desafio 5 - procurar na documentação do pandas o método query do Pandas.
# Desafio 6 - nos graficos, colocar título, labels, e melhorar a informação - procurar no matplotlib.
# Desafio 7 - renomear as colunas retirando os hifens - Python não trabalha bem com o hifen.
# Desafio 8 - Fazer um resumo do que foi aprendido com os dados, plotar gráficos para outras variáveis, e analisar.

# %% [markdown]
# #### Dia 1 - Sumário sobre o aprendizado:
# Realizado a importação do banco de dados; Exploração inicial dos dados para o estudo dada a especialidade do tema; Conhecimento inicial sbre as classes de informações das colunas do BD; Informações sobre o tamanho do BD - linhas e colunas, e categorias dos dados disponíveis; Aprendeu-se que  experimentos são realizados com o estudo em colônias de células para o desenvolvimento de novas drogas; Foram examinadas proporções entre alguns dados examinados; Aprendemos que os experimentos podem transcorrer num tempo de 24, 48 e 72 horas; Gráficos com biblioteca do pandas; Iniciado a aplicação da função 'query' para filtragem de informações, e finalmento iniciadoo cruzamento de dados para análise; Há desdobramentos possíveis para outras pesquisas, possilvemente a serem sinalizadas na medida em que avancemos na sua análise.

# %% [markdown]
# # 2 Dia - Estatísticas, visualização de dados e distribuições

# %% [markdown]
# Renomear a coluna 'droga' como 'composto'

# %%
mapa = {'droga' : 'composto'}
dados.rename(columns=mapa)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ####  Observa-se que a coluna no  DB inicial permanece como droga. Isto porque não foi feito a substituição do data-frame original.

# %% [markdown]
#  #### Fazer a troca da coluna do data-frame inicial

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ##### Quanto a modificação da substituição do nome da coluna droga para composto, registra-se um alerta! ... considerar que as funções já rodadas antes da modificação ficam  prejudicadas caso tenhamos que retornar acima!!!

# %%
dados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 3264f3b74       1
# 1d39c75d6       1
# 209a68d23       1
# b3f24a171       1
# b9ffc9444       1
# Name: composto, Length: 3289, dtype: int64

# %% [markdown]
# ##### Para plotar novo grafico, se escolheu tratar cinco elementos com maiores frequências;

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# #### Grafico com Seaborn

# %%
import seaborn as sns
import matplotlib.ticker as ticker
sns.set_style('dark')
sns.set_context('notebook', font_scale=1.2)
plt.figure(figsize=(8, 6))
variavel_ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order=dados['composto'].value_counts().head().index,palette='Set2')
variavel_ax.set_title('Top 5 compostos', fontsize=30)
variavel_ax.set_xlabel('Composto', fontsize=15)
variavel_ax.set_ylabel('Contagem', fontsize=15)
variavel_ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))  
plt.show()

# %% [markdown]
# #### Dia 2 - Desafios formulados para estudo
#
# 01 - Ordenar as barras do 'gráfico countplot' do maior para o menor;
# 02 - gerar novos gráficos, colocar títulos com Seaborn;
# 03 - Estudar como melhorar vizualização

# %% [markdown]
# #### Explorando agora os dados

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist()

# %%
dados['g-0'].hist(bins = 50)

# %%
dados['g-0'].hist(bins = 100)

# %%
dados['g-19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe().T
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
dados.loc[:,'g-0':'g-771'].describe().T.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f247f1d9d50>,
# ...
#       dtype=object)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %% [markdown]
# Desafio 03 - fazer graficos com Biblioteca Seaborn;
# Desafio 04 - Revisar as métricas da estatística do 'describe'

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g-0', data=dados)

# %%
sns.boxplot(x='g-0',y='tratamento', data=dados)

# %%
sns.boxplot(y='g-0', x='tratamento', data=dados)

# %%
sns.boxplot(y='g-0', x='tratamento', data=dados)
plt.figure(figsize=(10, 8))

# %% [markdown]
# ## Dia 2 - Sumário sobre o aprendizado:
# Estudou--se alterar nome de colunnas;  com biblioteca 'Seabron' criar novos gráficos tipo histograma;  aplicação da função 'loc';   comparação das informações plotadas em gráficos 'boxplot'
# versus 'histograma', e reflexões sobre a utilização de compostos (drogas) na pesquisa, com apoio da Especialista em Biogenética Profª. Vanessa Laiko.

# %% [markdown]
# # 3 Dia - Correlações, Causalidades e Relações entre genes

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ##### Agora, estudar uma forma de correlacionar algumas categorias de dados, como por  exemplo através das frequências, proporcionalidade, ...iniciar construindo tabela de frequência - pandas

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# #### Desafio 1 - Criar tabela de frequencia com o pandas.groupby;
# #### Desafio 2 - Normalizar o 'crosstab' pelas colunas;

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# #### Desafio 3 - Explorar outros agregadores no lugar da média, e comentar;
# #### Desafio 4 - Exploarar a função 'melt';

# %% [markdown]
# Agora, explorar uma possivel relação entre os experimentos g-0 e g-3

# %%
dados[['g-0','g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot('g-0', 'g-3', data=dados)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot('g-0', 'g-8', data=dados)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('g-0', 'g-8', data=dados, line_kws={'color':'red'})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ####  Agora, olhar para parte dos 'datas' que possam identificar outras relações dado que até o momento trabalhamos com o conjunto de todos os dados.

# %%
sns.lmplot('g-0', 'g-8', data=dados, line_kws={'color':'red'},col = 'tratamento')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('g-0', 'g-8', data=dados, line_kws={'color':'red'},col = 'tratamento', row='tempo')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
### Agora, estudar correlações entre algumas variáveis...

# %%
dados.loc[:,'g-0':'g-771']
# Out:
#           g-0     g-1     g-2     g-3  ...   g-768   g-769   g-770   g-771
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  0.3008  1.6490  0.2968 -0.0224
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.1626 -0.3340 -0.3289 -0.2718
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.5797  0.3143  0.8133  0.7923
# 3     -0.5138 -0.2491 -0.2656  0.5288  ...  0.1996  0.4374  0.1588 -0.0343
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -1.0020 -0.7534  0.5000 -0.6269
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.7221  0.5099 -0.1423  0.3806
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  0.5247  0.5438 -0.1875 -0.4751
# 23811  0.3942  0.3756  0.3109 -0.7389  ...  0.9778  0.2326 -0.6191  0.3603
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.1794  0.3109 -0.3491 -0.4741
# 23813 -0.8598  1.0240 -0.1361  0.7952  ...  1.5410  0.3633 -3.1970  2.2190
#
# [23814 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %% [markdown]
# ##### Notas: Relações próximas de (-1) e (+1) são fortes, são proporcionalmente correlacionados, uma variável afeta diretamentea outra variável. Qdo relações estão próximas de zero, são relações fracas, uma variável não afeta a outra. Valores negativos ou positivos vão se refletir na curva gráfica das expressões gênicas avaliadas. Correlação não necessariamente implica em causalidade.

# %% [markdown]
# Calculando a correlação, gerando a diagonal da matriz de correlação (Numpy) - biblioteca Seaborn - https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %%
import numpy as np

# Compute the correlation matrix
corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Compute the correlation matrix

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### Desafio 5 - Avaliamos correlações entre gens e entre tipos celulares. O desafio é calcular e analisar a correlação entre o 'g' e o 'c' (gens e tipos celulares) avaliados.  Dica atenção na formulação da diagonal enre g e c dado q têm qtds diferentes de variáveis.
# #### Desafio 6 - Estudar o código que plota a matriz da diagonal do heatmap;
# #### Desafio 7 - Refletir sobre o efeito biológico da correlação tão acentuada entre as células - coloque suas conclusões.

# %% [markdown]
# ## Dia 3 - Sumário do aprendizado
# Estudo das correlações;   Como plotar a curva (reta) na relação entre duas variaveis;    Como calcular correlações;   Opções na formulação e como analisar correlações.

# %% [markdown]
# # 4 Dia - Merge de Dados e Análise de Resultados

# %% [markdown]
# Importação arquivo .csv com resultados para se conhecer os mecanismos de ação  nos experimentos, ativação ou inibição de algum 'gen', fazer merge das tabelas, e novas análises

# %%
import pandas as pd
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Agora, identificar quantas vezes um determinado mecanismo de ação foi ativado (somar a coluna)

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum()
contagem_moa
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.drop('id', axis=1).select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# #### Agora, o foco será identificar quantas vezes uma determinada linha foi ativada e de que forma.

# %%
dados_resultados.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados.drop('id', axis=1).sum (axis=1).sort_values(ascending = False)
# Out:
# 21197    7
# 4849     7
# 19186    7
# 14316    7
# 20584    7
#         ..
# 6862     0
# 6861     0
# 11997    0
# 6859     0
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum (axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# #### Pergunta Van: agora, algum controle dos experimentos, recebeu alguma ativação? A resposta esperada é nula! ??? Vejamos!!! Rsss.  Tem-se duas bases de dados (BD): dados, dados_resultados.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# # criando a coluna n_moa
# # criando a coluna ativo_moa

# %%
dados_resultados['n moa'] = dados_resultados.drop('id', axis=1).sum (axis=1)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  ativo moa  n_moa
# 0  id_000644bb2                            0  ...       True   13.0
# 1  id_000779bfc                            0  ...      False    0.0
# 2  id_000a6266a                            0  ...       True   37.0
# 3  id_0015fd391                            0  ...      False    0.0
# 4  id_001626bd3                            0  ...       True   13.0
#
# [5 rows x 210 columns]

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...   13.0       True
# 1  id_000779bfc                            0  ...    0.0      False
# 2  id_000a6266a                            0  ...   37.0       True
# 3  id_0015fd391                            0  ...    0.0      False
# 4  id_001626bd3                            0  ...   13.0       True
#
# [5 rows x 211 columns]

# %% [markdown]
# #### Objetivo  agora é criar uma lista das colunas de interesse com a função 'merge' p visualizar se 'controle' foi ativado nos experimentos...(levar nº moa ativos e se ele foi ativo ou não em relação ao 'controle'- lista das colunas.)

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176   13.0       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371    0.0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931   37.0       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154    0.0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125   13.0       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento =="com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento =="com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# Desafios da aula 4:
#
# #### Desafio 1 - Encontrar o top 10 dos MOA - mecanismo de ação (inibidor, agonista,.... (observando que o caminho foi identificar quantas vezes um determinada coluna foi ativada).......;
# #### Desafio 2 - Criar coluna adicional entitulada 'eh controle' para quando na linha tratamento == controle
# #### Desafio 3 - Criar tres colunas para sinalizar a variavel categórica relacionada a 24,  48,  72 horas,com True ou False
# #### Desafio 4 - Estudar sobre combinações de DF DataFrame
# #### Desafio 5 - fazer análise mais detalhada do boxplot final - escolhendo uma droga (composto), a que mais aparecer e comparar com 'controle' nos diferentes tempos e
# #### Desafio 6 - Verificar se a variável 'tempo' fez ativar algum composto nestes experimentos.
# #### Desafio 7 - Descobrir se algum composto ativa ou não ativa MOAs diferentes
# #### Desafio 8 - Identificar o composto que foi mais utilizado e
# #### Desafio 9 - Resumir o aprendizado

# %% [markdown]
# ## Sumário do aprendizado da aula 4.
# Procedemos a investigação de nova base de dados com os resultados dos mecanismos e dos experimentos;
# Identificou-se que um determinado composto pode ativar diferentes experimentos;
# Estruturamos DF para os novos resultados;
# Realizado merge das planilhas de dados iniciais e de resultados;
# Aprendemos a utiliz
# Utilizamos boxplot para comparar diferentes resultados
#
#
# Contribuição do Gustavo Quadra — Hoje 06.05.21 às 17:29 Pessoal, gostaria de saber se estou entendendo a parte biológica da mesma forma que vocês (seria bom se a @Vanessa Leiko pudesse corrigir hehehe) :
#
# id : identificador para um experimento
# G's : expressão gênica = Processo pelo qual a informação hereditária de um gene, forma uma proteína ou RNA
# C's : viabilidade celular = Analisar células de uma cultura celular, afim de avaliar sua atividade.
# composto / droga = Placebo (talvez) para casos com controle e remédios / substâncias diferentes para casos com droga
# MOA : Mecanismo de ação do Alvo : interação bioquímica entre uma droga utilizada e um alvo (enzima (terminados com -ase), proteína, etc)

# %% [markdown]
# # 5 Dia - Modelo de Machine Learning, Sci-kit Learning e desafios envolvidos

# %% [markdown]
# Bibliografia:
#
# Post sobre pesquisa na indústria farmacêutica - acesso em 04.05.2021 - https://science.talknmb.com.br/pesquisa-clinica-industria-farmaceutica/
#
# Calculo da correlação:   https://seaborn.pydata.org/examples/many_pairwise_correlations.html
